# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.rand(2)
A = np.random.rand(2,2)
# Out:
# array([[0.8383397 , 0.00967146],
#        [0.24745397, 0.64415035]])

# %%
b1 = A.dot(x)
b1
# Out:
# array([0.13827397, 0.64803777])

# %%
krylov = []
cur =x
fig,ax = plt.subplots()
for i in range(0,10):
    plt.plot([0,cur[0]],[0, cur[1]])
    krylov.append(cur)
    ax.annotate(i, xy = cur)
    cur = A.dot(cur)
